# %%
# install python - Done
# install VSC - Done
# install pandas - Done
# install jupyter - Done
# select python env - Done
# run the code - Done 
# *Not sure why need to restart first before using it, eventhough previously already working

import pandas as pd

# Create a sample dataset
data = {'Name': ['John', 'Mary', 'David'], 
        'Age': [25, 31, 42], 
        'City': ['New York', 'Chicago', 'Los Angeles']}

# Create a pandas DataFrame
df = pd.DataFrame(data)

# Print the DataFrame
print(df)
# Out:
#     Name  Age         City
# 0   John   25     New York
# 1   Mary   31      Chicago
# 2  David   42  Los Angeles

# %%
# import excel - Fail
# Find the noun

df = pd.read_excel("Festo Vertrieb GmbH & Co. KG.xlsx") 
print(df)
# Out:
#                      Company name  \
# 0    Festo Vertrieb GmbH & Co. KG
# 1    Festo Vertrieb GmbH & Co. KG
# 2    Festo Vertrieb GmbH & Co. KG
# 3    Festo Vertrieb GmbH & Co. KG
# 4    Festo Vertrieb GmbH & Co. KG
# ..                            ...
# 776  Festo Vertrieb GmbH & Co. KG
# 777  Festo Vertrieb GmbH & Co. KG
# 778  Festo Vertrieb GmbH & Co. KG
# 779  Festo Vertrieb GmbH & Co. KG
# 780  Festo Vertrieb GmbH & Co. KG
#
#                                    Product description
# 0    Teile-Nr.;Benennung;Typ;Identcode 1;Identcode ...
# 1    1492136;Magnetventil;VZWF-B-L-M22C-G12-135-E-1...
# 2    564212;Magnetventil;VUVG;VUVG-L14-M52-AZT-G18-...
# 3    186191;Y-Steckverschraubung;QSYL-G1/4-6; ; ; ;...
# 4    544002;Mini-Schlitten;DGSL-16-80-Y3A; ; ; ;ST;...
# ..                                                 ...
# 776  186097;Steckverschraubung;QS-G1/4-6; ; ; ;ST;1...
# 777  175092;Befestigungsbausatz;SMBR-8-10; ; ; ;ST;...
# ...

# %%
result = df['Product description'].str.split(';').str[1:].str.join(' ')
print(result)
# Out:
# 0      Benennung Typ Identcode 1 Identcode 2 Hub in m...
# 1      Magnetventil VZWF-B-L-M22C-G12-135-E-1P4-10-R1...
# 2      Magnetventil VUVG VUVG-L14-M52-AZT-G18-1R8L   ...
# 3        Y-Steckverschraubung QSYL-G1/4-6       ST 1
# 4           Mini-Schlitten DGSL-16-80-Y3A       ST 1
#                              ...
# 776         Steckverschraubung QS-G1/4-6       ST 10
# 777         Befestigungsbausatz SMBR-8-10       ST 1
# 778                         Kunststoffschlauch PUN-H-4X0
# 779      Manometer MA-40-10-1/8       ST 1 A2U00118654
# 780                    Ventil CPVSC1-M-QX       ST 1
# Name: Product description, Length: 781, dtype: object

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\WanRahim\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\WanRahim\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\WanRahim\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
print(nltk.__version__)
# Out:
# 3.9.1

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

def extract_nouns(text):
    tokens = word_tokenize(text)
    tagged = pos_tag(tokens)
    nouns = [word for word, pos in tagged if pos in ['NN', 'NNS', 'NNP', 'NNPS']]
    return ' '.join(nouns)

print(df['Product description'])  # print the entire column

# brokennnn!!!!! --> Solution is download the correct file. (above)
df['Nouns'] = df['Product description'].apply(extract_nouns)  # apply the extract_nouns function
print(df['Nouns'])  # print the resulting nouns column
# Out:
# 0      Teile-Nr.;Benennung;Typ;Identcode 1;Identcode ...
# 1      1492136;Magnetventil;VZWF-B-L-M22C-G12-135-E-1...
# 2      564212;Magnetventil;VUVG;VUVG-L14-M52-AZT-G18-...
# 3      186191;Y-Steckverschraubung;QSYL-G1/4-6; ; ; ;...
# 4      544002;Mini-Schlitten;DGSL-16-80-Y3A; ; ; ;ST;...
#                              ...
# 776    186097;Steckverschraubung;QS-G1/4-6; ; ; ;ST;1...
# 777    175092;Befestigungsbausatz;SMBR-8-10; ; ; ;ST;...
# 778                 8048677;Kunststoffschlauch;PUN-H-4X0
# 779    359874;Manometer;MA-40-10-1/8; ; ; ;ST;1;A2U00...
# 780             548906;Ventil;CPVSC1-M-QX; ; ; ;ST;1; ;
# Name: Product description, Length: 781, dtype: object
# 0      Teile-Nr Benennung Typ Identcode Identcode Hub...
# 1      Magnetventil VZWF-B-L-M22C-G12-135-E-1P4-10-R1 ST
# 2         Magnetventil VUVG VUVG-L14-M52-AZT-G18-1R8L ST
# 3                    Y-Steckverschraubung QSYL-G1/4-6 ST
# 4                       Mini-Schlitten DGSL-16-80-Y3A ST
# ...

# %%
df['Nouns'] = df['Product description'].apply(extract_nouns)  # apply the extract_nouns function
print(df['Nouns'])  # print the resulting nouns column
# Out:
# Tagged tokens: [('Teile-Nr', 'NNP'), ('.', '.'), (';', ':'), ('Benennung', 'NNP'), (';', ':'), ('Typ', 'NNP'), (';', ':'), ('Identcode', 'NNP'), ('1', 'CD'), (';', ':'), ('Identcode', 'NNP'), ('2', 'CD'), (';', ':'), ('Hub', 'NNP'), ('in', 'IN'), ('mm', 'NN'), (';', ':'), ('Mengeneinheit', 'NNP'), (';', ':'), ('Verpackungseinheit', 'NNP'), (';', ':'), ('Meine', 'NNP'), ('Bezeichnung', 'NNP'), (';', ':')]
# Tagged tokens: [('1492136', 'CD'), (';', ':'), ('Magnetventil', 'NNP'), (';', ':'), ('VZWF-B-L-M22C-G12-135-E-1P4-10-R1', 'NNP'), (';', ':'), (';', ':'), (';', ':'), (';', ':'), ('ST', 'NNP'), (';', ':'), ('1', 'CD'), (';', ':'), (';', ':')]
# Tagged tokens: [('564212', 'CD'), (';', ':'), ('Magnetventil', 'NNP'), (';', ':'), ('VUVG', 'NNP'), (';', ':'), ('VUVG-L14-M52-AZT-G18-1R8L', 'NNP'), (';', ':'), (';', ':'), (';', ':'), ('ST', 'NNP'), (';', ':'), ('1', 'CD'), (';', ':'), (';', ':')]
# ...
